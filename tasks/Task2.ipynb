# %% [markdown]
# # Dashboarding with PowerBI

# %% [markdown]
# ## Task
#
# ### 2) Create a Dashboard showing the following charts:
#
# * Number of people hired every year.
#
#
# * Number of total managers in each department.
#
#
# * Average salary of each department.
#
#
# * Number of employees between the ages of 21 to 30 at the time of hiring of each gender.

# %% [markdown]
# ![Screenshot%20from%202022-10-17%2013-22-32.png](attachment:Screenshot%20from%202022-10-17%2013-22-32.png)

# %% [markdown]
# ![Screenshot%20from%202022-10-17%2013-19-50.png](attachment:Screenshot%20from%202022-10-17%2013-19-50.png)

# %% [markdown]
# ![Screenshot%20from%202022-10-17%2013-20-41.png](attachment:Screenshot%20from%202022-10-17%2013-20-41.png)
